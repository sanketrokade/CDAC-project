# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("./data/total_execution_time.csv")

# %%
df1.head(15)
# Out:
#     ncsf      seq      MPI     CUDA
# 0    500    0.712   15.630    1.644
# 1   1000    3.588   16.701    4.972
# 2   1500    9.325   23.532    8.053
# 3   2000   20.185   35.472   15.553
# 4   2500   36.063   55.489   21.474
# 5   3000   59.922   87.180   31.791
# 6   3500   88.658  137.612   43.733
# 7   4000  141.846  176.259   65.627
# 8   4500  208.780  235.041   79.031
# 9   5000  268.101  300.657  109.095
# 10  5500  342.164  392.637  135.159
# 11  6000  429.413  482.830  178.560
# 12  6500  531.598  503.222  218.067
# 13  7000  619.932  649.353  257.448

# %%
plt.plot(df1['ncsf'],df1['seq'],'o-',label='Sequential')
plt.plot(df1['ncsf'],df1['MPI'],'o-',label='MPI')
plt.plot(df1['ncsf'],df1['CUDA'],'o-',label='CUDA + MPI')
plt.xlabel('Matrix size')
plt.ylabel('Total Execution time (sec)')
plt.legend()

# %%
df2 = pd.read_csv("./data/diagonalization_time.csv")
df2.head(15)
# Out:
#     ncsf       seq       MPI     CUDA
# 0    500    0.1540    0.2350   0.1770
# 1   1000    0.7710    1.2630   0.2470
# 2   1500    2.5470    3.2995   0.3550
# 3   2000    6.5890   11.2490   0.5396
# 4   2500   14.1076   21.6110   0.8056
# 5   3000   25.0905   42.5970   1.1716
# 6   3500   40.7310   78.9580   1.7105
# 7   4000   64.8800  103.8000   2.4694
# 8   4500  120.9720  151.6670   3.3083
# 9   5000  151.6470  200.6500   4.2855
# 10  5500  212.1290  271.8590   5.5192
# 11  6000  255.7720  351.5770   7.1157
# 12  6500  330.8390  350.8380   8.7790
# 13  7000  387.6890  463.0250  10.6820

# %%
plt.plot(df2['ncsf'],df2['seq'],'o-',label='Sequential, using LAPACK function')
plt.plot(df2['ncsf'],df2['MPI'],'o-',label='MPI, using LAPACK function')
plt.plot(df2['ncsf'],df2['CUDA'],'o-',label='CUDA + MPI, using cuSolver function')
plt.xlabel('Matrix size')
plt.ylabel('Diagonalization execution time (sec)')
plt.legend()

# %%
df3 = pd.read_csv("./data/matrix_multiplication_time.csv")
df3.head(15)
# Out:
#     ncsf     seq      MPI     CUDA
# 0    500  0.0050   0.0133   0.0423
# 1   1000  0.2370   0.0947   0.1042
# 2   1500  0.0783   0.1551   0.1944
# 3   2000  0.1760   0.4460   0.4012
# 4   2500  0.3680   0.7970   0.7367
# 5   3000  0.6521   1.3790   1.2241
# 6   3500  1.0349   2.3050   1.9107
# 7   4000  1.6340   3.1504   2.8140
# 8   4500  2.7090   4.4770   3.9641
# 9   5000  3.6215   6.3230   5.5305
# 10  5500  5.4528   8.7000   7.9800
# 11  6000  5.8809  10.0590  11.0120
# 12  6500  7.9107  13.0690  14.1020
# 13  7000  9.5482  14.6640  17.8110

# %%
plt.plot(df3['ncsf'],df3['seq'],'o-',label='Sequential, using Blas function')
plt.plot(df3['ncsf'],df3['MPI'],'o-',label='MPI, using Blas function')
plt.plot(df3['ncsf'],df3['CUDA'],'o-',label='CUDA + MPI, using cuBlas function')
plt.xlabel('Matrix size')
plt.ylabel('Matrix Multiplication execution time (sec)')
plt.legend()

# %%
df4 = pd.read_csv("./data/avg_loop_time.csv")
df4.head(15)
# Out:
#     ncsf     seq   MPI    CUDA
# 0    500  0.0081  0.27  0.0134
# 1   1000  0.0440  0.33  0.0520
# 2   1500  0.1080  0.36  0.1110
# 3   2000  0.2110  0.38  0.2310
# 4   2500  0.3440  0.45  0.3040
# 5   3000  0.6200  0.62  0.4480
# 6   3500  0.7800  0.86  0.6150
# 7   4000  1.1200  1.05  0.9230
# 8   4500  1.3770  1.27  1.1100
# 9   5000  1.8080  1.46  1.4800
# 10  5500  2.2100  1.53  1.7600
# 11  6000  2.6300  1.63  2.3400
# 12  6500  3.2700  2.38  3.0200
# 13  7000  3.5800  2.65  3.1200

# %%
plt.plot(df4['ncsf'],df4['seq'],'o-',label='Sequential')
plt.plot(df4['ncsf'],df4['MPI'],'o-',label='MPI')
plt.plot(df4['ncsf'],df4['CUDA'],'o-',label='CUDA + MPI')
plt.xlabel('Matrix size')
plt.ylabel('Avg. loop execution time (sec)')
plt.legend()
